# %% [markdown]
# # BabyECG

# %%
from models.GaussianSmoothedBabyECG import main
main()
# Out:
# times_t [[960, 970, 990, 1000, 1020, 1030, 1040, 1060]] |
# T = 2048 |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications of [129 130 123 ... 147 149 161] ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:00.772221.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-21 16:09:28.463306 ...
# Weights computation complete for Montecarlo 1 at 2024-11-21 16:09:28.572874; time elapsed = 0:00:00.109568.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2024-11-21 16:09:28.580560 ...
# Wasserstein distances at 2024-11-21 16:09:28.722416; time elapsed = 0:00:00.141856.
# ...
