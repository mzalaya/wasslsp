# %% [markdown]
# # HRV

# %%
from models.GaussianSmoothedHRV import main
main()
# Out:
# times_t [[7950, 8080, 8150, 8390, 8500, 8650, 8900, 8960]] |
# T = 17178 |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications of [182.9267735  182.9267735  154.63937454 ... 148.51485148 140.18691589
#  142.85714286] ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:01.223007.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-21 16:14:00.425671 ...
# Weights computation complete for Montecarlo 1 at 2024-11-21 16:14:00.708677; time elapsed = 0:00:00.283006.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2024-11-21 16:14:00.722677 ...
# Wasserstein distances at 2024-11-21 16:14:01.433594; time elapsed = 0:00:00.710917.
# ...
