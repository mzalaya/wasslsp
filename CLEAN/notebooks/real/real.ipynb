# %% [markdown]
# # Gaussian-noised Real Datasets

# %%
import sys
sys.path.append('D:/Users/tiniojan/ExperimentsPhD/11-18-24/wasslsp/CLEAN/')

# %% [markdown]
# # BabyECG

# %%
from models.GaussianSmoothedBabyECG import main
main()
# Out:
# times_t [[960, 970, 990, 1000, 1020, 1030, 1040, 1060]] |
# T = 2048 |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications of [129 130 123 ... 147 149 161] ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:00.751449.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-20 15:23:52.620872 ...
# Weights computation complete for Montecarlo 1 at 2024-11-20 15:23:52.725480; time elapsed = 0:00:00.104608.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2024-11-20 15:23:52.741166 ...
# Wasserstein distances at 2024-11-20 15:23:52.971603; time elapsed = 0:00:00.230437.
# ...

# %% [markdown]
# # SP500

# %%
from models.GaussianSmoothedSP500 import main
main()
# Out:
# times_t [[3850, 3920, 3990, 4060, 4130, 4200, 4280, 4350]] |
# T = 8372 |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications of [ 0.00613605 -0.00109132  0.01484305 ... -0.00013057 -0.0029487
#   0.01079402] ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:00.540037.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-20 15:23:54.478601 ...
# Weights computation complete for Montecarlo 1 at 2024-11-20 15:23:54.662212; time elapsed = 0:00:00.183611.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2024-11-20 15:23:54.672210 ...
# Wasserstein distances at 2024-11-20 15:23:55.330938; time elapsed = 0:00:00.658728.
# ...

# %% [markdown]
# # HRV

# %%
from models.GaussianSmoothedHRV import main
main()
# Out:
# times_t [[7950, 8080, 8150, 8390, 8500, 8650, 8900, 8960]] |
# T = 17178 |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications of [182.9267735  182.9267735  154.63937454 ... 148.51485148 140.18691589
#  142.85714286] ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:00.446224.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-20 15:23:56.865279 ...
# Weights computation complete for Montecarlo 1 at 2024-11-20 15:23:57.128251; time elapsed = 0:00:00.262972.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2024-11-20 15:23:57.131879 ...
# Wasserstein distances at 2024-11-20 15:23:57.836211; time elapsed = 0:00:00.704332.
# ...
