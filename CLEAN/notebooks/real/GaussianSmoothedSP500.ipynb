# %% [markdown]
# # SP500

# %%
from models.GaussianSmoothedSP500 import main
main()
# Out:
# times_t [[3850, 3920, 3990, 4060, 4130, 4200, 4280, 4350]] |
# T = 8372 |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications of [ 0.00613605 -0.00109132  0.01484305 ... -0.00013057 -0.0029487
#   0.01079402] ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:01.240420.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-21 16:12:47.701903 ...
# Weights computation complete for Montecarlo 1 at 2024-11-21 16:12:47.888067; time elapsed = 0:00:00.186164.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2024-11-21 16:12:47.902460 ...
# Wasserstein distances at 2024-11-21 16:12:48.563438; time elapsed = 0:00:00.660978.
# ...
