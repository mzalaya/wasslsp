# %% [markdown]
# # Gaussian tvAR(1)

# %%
import sys
sys.path.append('D:/Users/tiniojan/ExperimentsPhD/11-18-24/wasslsp/CLEAN')

# %%
from models.GaussiantvAR1 import main
main()
# Out:
# times_T = 5000 |
# times_t_dict [[2400, 2410, 2430, 2440, 2460, 2470, 2490, 2500, 2510, 2530, 2540, 2560, 2570, 2590, 2600]] |
# n_replications = 10 | device = cpu
# times_T = 10000 |
# times_t_dict [[4800, 4830, 4860, 4890, 4910, 4940, 4970, 5000, 5030, 5060, 5090, 5110, 5140, 5170, 5200]] |
# n_replications = 10 | device = cpu
# times_T = 15000 |
# times_t_dict [[7200, 7240, 7290, 7330, 7370, 7410, 7460, 7500, 7540, 7580, 7630, 7670, 7710, 7760, 7800]] |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications with T-samples of process ...
# Montecarlo 1 completed.
# Montecarlo 2 completed.
# Simulation completed; time elapsed = 0:00:00.983810.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-20 16:03:58.434644 ...
# ...

# %% [markdown]
# # Gaussian tvAR(2)

# %%
from models.GaussiantvAR2 import main
main()
# Out:
# times_T = 5000 |
# times_t_dict [[2400, 2410, 2430, 2440, 2460, 2470, 2490, 2500, 2510, 2530, 2540, 2560, 2570, 2590, 2600]] |
# n_replications = 10 | device = cpu
# times_T = 10000 |
# times_t_dict [[4800, 4830, 4860, 4890, 4910, 4940, 4970, 5000, 5030, 5060, 5090, 5110, 5140, 5170, 5200]] |
# n_replications = 10 | device = cpu
# times_T = 15000 |
# times_t_dict [[7200, 7240, 7290, 7330, 7370, 7410, 7460, 7500, 7540, 7580, 7630, 7670, 7710, 7760, 7800]] |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications with T-samples of process ...
# Montecarlo 1 completed.
# Montecarlo 2 completed.
# Simulation completed; time elapsed = 0:00:01.000738.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-20 16:08:13.399781 ...
# ...

# %% [markdown]
# # Cauchy tvAR(2)

# %%
from models.CauchytvAR2 import main
main()
# Out:
# times_T = 5000 |
# times_t_dict [[2400, 2410, 2430, 2440, 2460, 2470, 2490, 2500, 2510, 2530, 2540, 2560, 2570, 2590, 2600]] |
# n_replications = 10 | device = cpu
# times_T = 10000 |
# times_t_dict [[4800, 4830, 4860, 4890, 4910, 4940, 4970, 5000, 5030, 5060, 5090, 5110, 5140, 5170, 5200]] |
# n_replications = 10 | device = cpu
# times_T = 15000 |
# times_t_dict [[7200, 7240, 7290, 7330, 7370, 7410, 7460, 7500, 7540, 7580, 7630, 7670, 7710, 7760, 7800]] |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications with T-samples of process ...
# Montecarlo 1 completed.
# Montecarlo 2 completed.
# Simulation completed; time elapsed = 0:00:01.069462.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-20 16:08:39.756565 ...
# ...

# %% [markdown]
# # Gaussian tvTAR(1)

# %%
from models.GaussiantvTAR1 import main
main()
# Out:
# times_T = 5000 |
# times_t_dict [[2400, 2410, 2430, 2440, 2460, 2470, 2490, 2500, 2510, 2530, 2540, 2560, 2570, 2590, 2600]] |
# n_replications = 10 | device = cpu
# times_T = 10000 |
# times_t_dict [[4800, 4830, 4860, 4890, 4910, 4940, 4970, 5000, 5030, 5060, 5090, 5110, 5140, 5170, 5200]] |
# n_replications = 10 | device = cpu
# times_T = 15000 |
# times_t_dict [[7200, 7240, 7290, 7330, 7370, 7410, 7460, 7500, 7540, 7580, 7630, 7670, 7710, 7760, 7800]] |
# n_replications = 10 | device = cpu
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications with T-samples of process ...
# Montecarlo 1 completed.
# Montecarlo 2 completed.
# Simulation completed; time elapsed = 0:00:01.032257.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2024-11-20 16:07:31.834980 ...
# ...
